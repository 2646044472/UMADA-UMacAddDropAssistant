# %% [markdown]
# Set your parameters

# %%
# What is your major?
MAJOR_SUPPORT = "CISC"
# Do you need FE courses recommendation?
FE_SUPPORT = False
# What is the academic year now?
YEAR_SUPPORT = "2024a"
# How many suggestion do you want?
SUGGESTION_NUM = 30

# %%
import numpy as np
import pandas as pd
from datetime import datetime, timedelta

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.expand_frame_repr', False)

# %% [markdown]
# Convert your timetable into special data structure. You can use AI tools like GPT-4 or Claude-3.5 to accomplish this. In this case, you may need to use the following prompt:
# ```
# my_timetable = [
# {
# "course_code": "GEST1009",
# "day": "MON",
# "start_time": "08:30",
# "end_time": "09:45",
# "type": "Lecture"
# },
# {
# "course_code": "GEST1009",
# "day": "THU",
# "start_time": "08:30",
# "end_time": "09:45",
# "type": "Lecture"
# },
# {
# "course_code": "CISC1002",
# "day": "MON",
# "start_time": "11:30",
# "end_time": "12:45",
# "type": "Lecture"
# },
# # ... (continue for all other classes)
# ]
#
# Convert all the data from the timetable image into the format shown above.
# ```

# %%
timetable = [
    {
        "course_code": "GEST1009",
        "day": "MON",
        "start_time": "08:30",
        "end_time": "09:45",
        "type": "Lecture"
    },
    {
        "course_code": "GEST1009",
        "day": "THU",
        "start_time": "08:30",
        "end_time": "09:45",
        "type": "Lecture"
    },
    {
        "course_code": "CISC1002",
        "day": "MON",
        "start_time": "11:30",
        "end_time": "12:45",
        "type": "Lecture"
    },
    {
        "course_code": "CISC1002",
        "day": "THU",
        "start_time": "11:30",
        "end_time": "12:45",
        "type": "Lecture"
    },
    {
        "course_code": "CISC1002",
        "day": "FRI",
        "start_time": "10:00",
        "end_time": "11:15",
        "type": "Lab/Tutorial"
    },
    {
        "course_code": "GEGA1000",
        "day": "TUE",
        "start_time": "14:30",
        "end_time": "15:45",
        "type": "Lecture"
    },
    {
        "course_code": "GEGA1000",
        "day": "FRI",
        "start_time": "14:30",
        "end_time": "15:45",
        "type": "Lecture"
    },
    {
        "course_code": "CISC2001",
        "day": "MON",
        "start_time": "16:00",
        "end_time": "17:15",
        "type": "Lecture"
    },
    {
        "course_code": "CISC2001",
        "day": "THU",
        "start_time": "16:00",
        "end_time": "17:15",
        "type": "Lecture"
    },
    {
        "course_code": "CISC2001",
        "day": "FRI",
        "start_time": "17:30",
        "end_time": "18:45",
        "type": "Lab/Tutorial"
    },
    {
        "course_code": "CISC2003",
        "day": "TUE",
        "start_time": "16:00",
        "end_time": "17:15",
        "type": "Lecture"
    },
    {
        "course_code": "CISC2003",
        "day": "WED",
        "start_time": "16:00",
        "end_time": "17:15",
        "type": "Lab/Tutorial"
    },
    {
        "course_code": "CISC2003",
        "day": "FRI",
        "start_time": "16:00",
        "end_time": "17:15",
        "type": "Lecture"
    },
    {
        "course_code": "HONR2003",
        "day": "WED",
        "start_time": "18:30",
        "end_time": "21:15",
        "type": "Lecture"
    }
]

# %%
cm = pd.read_csv("2024a/cm.csv").dropna(axis=0)
ge = pd.read_csv("2024a/ge.csv").dropna(axis=0)

# %%
if FE_SUPPORT == True:
    df = pd.concat([cm, ge], ignore_index=True)
else:
    cm = cm[cm['course_name'].str.startswith(f'{MAJOR_SUPPORT}', na=False)]
    df = pd.concat([cm, ge], ignore_index=True)

# %%
grade_order = {
    'A+': 12, 'A': 11, 'A-': 10,
    'B+': 9, 'B': 8, 'B-': 7,
    'C+': 6, 'C': 5, 'C-': 4,
    'D+': 3, 'D': 2, 'D-': 1,
    'F': 0
}

def grade_to_numeric(grade):
    return grade_order.get(grade, -1) 

df = df.sort_values(
    by=['overall_grade', 'course_name', 'name'],
    key=lambda x: x.map(lambda y: grade_to_numeric(y) if x.name == 'overall_grade' else y),
    ascending=[False, True, True]
)

# %%
def parse_time(time_str):
    return datetime.strptime(time_str, '%H:%M')

def check_conflict(existing_class, new_class):
    if existing_class['day'] != new_class['day']:
        return False
    
    existing_start = parse_time(existing_class['start_time'])
    existing_end = parse_time(existing_class['end_time'])
    new_start = parse_time(new_class['start_time'])
    new_end = parse_time(new_class['end_time'])
    
    return (existing_start <= new_start < existing_end) or \
           (existing_start < new_end <= existing_end) or \
           (new_start <= existing_start and existing_end <= new_end)

def parse_course_time(time_str):
    time_slots = []
    for slot in time_str.split('&'):
        day, time_range = slot.strip().split(' ', 1)
        start_time, end_time = time_range.split('-')
        time_slots.append({
            'day': day,
            'start_time': start_time,
            'end_time': end_time
        })
    return time_slots

def has_conflict_with_timetable(course_time, my_timetable):
    course_slots = parse_course_time(course_time)
    for new_slot in course_slots:
        for existing_class in my_timetable:
            if check_conflict(existing_class, new_slot):
                return True
    return False

# %%
df = df[~df['time'].apply(lambda x: has_conflict_with_timetable(x, timetable))]

# %%
def style_dataframe(df):
    def highlight_grades(val):
        color_map = {
            'A': '#4CAF50',  
            'A-': '#8BC34A',
            'B+': '#2196F3', 
            'B': '#03A9F4',
            'B-': '#00BCD4',
            'C+': '#FFC107', 
            'C': '#FFB300',
            'C-': '#FFA000',
            'D': '#FF5722', 
            'F': '#F44336' 
        }
        return f'color: {color_map.get(val, "#212529")}; font-weight: bold;'

    return (df.style
            .set_properties(**{
                'background-color': '#f8f9fa',
                'color': '#212529',
                'border-color': '#dee2e6',
                'font-family': 'Arial, sans-serif',
                'font-size': '12px',
                'text-align': 'left',
                'white-space': 'normal',  
                'max-width': '150px'
            })
            .set_table_styles([
                {'selector': 'th', 'props': [
                    ('background-color', '#e9ecef'),
                    ('color', '#495057'),
                    ('font-weight', 'bold'),
                    ('text-align', 'left'),
                    ('padding', '12px'),
                    ('border-bottom', '2px solid #dee2e6')
                ]},
                {'selector': 'td', 'props': [('padding', '12px')]},
                {'selector': 'tr:nth-of-type(even)', 'props': [('background-color', '#ffffff')]},
            ])
            .map(highlight_grades, subset=['overall_grade', 'grade'])
            .highlight_max(subset=['difficulty', 'useful'], color='#fce4ec')
            .highlight_min(subset=['difficulty', 'useful'], color='#e8f5e9')
           )
def show():
    styled_df = style_dataframe(df)
    display(styled_df)

# %%
show()
# Out:
# <style type="text/css">
# #T_d96a1 th {
#   background-color: #e9ecef;
#   color: #495057;
#   font-weight: bold;
#   text-align: left;
#   padding: 12px;
#   border-bottom: 2px solid #dee2e6;
# }
# #T_d96a1 td {
#   padding: 12px;
# }
# #T_d96a1 tr:nth-of-type(even) {
#   background-color: #ffffff;
# }
# #T_d96a1_row0_col0, #T_d96a1_row0_col1, #T_d96a1_row0_col2, #T_d96a1_row0_col7, #T_d96a1_row0_col8, #T_d96a1_row1_col0, #T_d96a1_row1_col1, #T_d96a1_row1_col2, #T_d96a1_row1_col7, #T_d96a1_row1_col8, #T_d96a1_row2_col0, #T_d96a1_row2_col1, #T_d96a1_row2_col2, #T_d96a1_row2_col7, #T_d96a1_row2_col8, #T_d96a1_row3_col0, #T_d96a1_row3_col1, #T_d96a1_row3_col2, #T_d96a1_row3_col7, #T_d96a1_row3_col8, #T_d96a1_row4_col0, #T_d96a1_row4_col1, #T_d96a1_row4_col2, #T_d96a1_row4_col5, #T_d96a1_row4_col6, #T_d96a1_row4_col7, #T_d96a1_row4_col8, #T_d96a1_row5_col0, #T_d96a1_row5_col1, #T_d96a1_row5_col2, #T_d96a1_row5_col5, #T_d96a1_row5_col6, #T_d96a1_row5_col7, #T_d96a1_row5_col8, #T_d96a1_row6_col0, #T_d96a1_row6_col1, #T_d96a1_row6_col2, #T_d96a1_row6_col5, #T_d96a1_row6_col6, #T_d96a1_row6_col7, #T_d96a1_row6_col8, #T_d96a1_row7_col0, #T_d96a1_row7_col1, #T_d96a1_row7_col2, #T_d96a1_row7_col5, #T_d96a1_row7_col6, #T_d96a1_row7_col7, #T_d96a1_row7_col8, #T_d96a1_row8_col0, #T_d96a1_row8_col1, #T_d96a1_row8_col2, #T_d96a1_row8_col5, #T_d96a1_row8_col6, #T_d96a1_row8_col7, #T_d96a1_row8_col8, #T_d96a1_row9_col0, #T_d96a1_row9_col1, #T_d96a1_row9_col2, #T_d96a1_row9_col5, #T_d96a1_row9_col6, #T_d96a1_row9_col7, #T_d96a1_row9_col8, #T_d96a1_row10_col0, #T_d96a1_row10_col1, #T_d96a1_row10_col2, #T_d96a1_row10_col5, #T_d96a1_row10_col7, #T_d96a1_row10_col8, #T_d96a1_row11_col0, #T_d96a1_row11_col1, #T_d96a1_row11_col2, #T_d96a1_row11_col5, #T_d96a1_row11_col6, #T_d96a1_row11_col7, #T_d96a1_row11_col8, #T_d96a1_row12_col0, #T_d96a1_row12_col1, #T_d96a1_row12_col2, #T_d96a1_row12_col5, #T_d96a1_row12_col6, #T_d96a1_row12_col7, #T_d96a1_row12_col8, #T_d96a1_row13_col0, #T_d96a1_row13_col1, #T_d96a1_row13_col2, #T_d96a1_row13_col5, #T_d96a1_row13_col6, #T_d96a1_row13_col7, #T_d96a1_row13_col8, #T_d96a1_row14_col0, #T_d96a1_row14_col1, #T_d96a1_row14_col2, #T_d96a1_row14_col5, #T_d96a1_row14_col6, #T_d96a1_row14_col7, #T_d96a1_row14_col8, #T_d96a1_row15_col0, #T_d96a1_row15_col1, #T_d96a1_row15_col2, #T_d96a1_row15_col5, #T_d96a1_row15_col6, #T_d96a1_row15_col7, #T_d96a1_row15_col8, #T_d96a1_row16_col0, #T_d96a1_row16_col1, #T_d96a1_row16_col2, #T_d96a1_row16_col5, #T_d96a1_row16_col6, #T_d96a1_row16_col7, #T_d96a1_row16_col8, #T_d96a1_row17_col0, #T_d96a1_row17_col1, #T_d96a1_row17_col2, #T_d96a1_row17_col5, #T_d96a1_row17_col6, #T_d96a1_row17_col7, #T_d96a1_row17_col8, #T_d96a1_row18_col0, #T_d96a1_row18_col1, #T_d96a1_row18_col2, #T_d96a1_row18_col5, #T_d96a1_row18_col6, #T_d96a1_row18_col7, #T_d96a1_row18_col8, #T_d96a1_row19_col0, #T_d96a1_row19_col1, #T_d96a1_row19_col2, #T_d96a1_row19_col5, #T_d96a1_row19_col6, #T_d96a1_row19_col7, #T_d96a1_row19_col8, #T_d96a1_row20_col0, #T_d96a1_row20_col1, #T_d96a1_row20_col2, #T_d96a1_row20_col5, #T_d96a1_row20_col6, #T_d96a1_row20_col7, #T_d96a1_row20_col8, #T_d96a1_row21_col0, #T_d96a1_row21_col1, #T_d96a1_row21_col2, #T_d96a1_row21_col5, #T_d96a1_row21_col6, #T_d96a1_row21_col7, #T_d96a1_row21_col8, #T_d96a1_row22_col0, #T_d96a1_row22_col1, #T_d96a1_row22_col2, #T_d96a1_row22_col5, #T_d96a1_row22_col6, #T_d96a1_row22_col7, #T_d96a1_row22_col8, #T_d96a1_row23_col0, #T_d96a1_row23_col1, #T_d96a1_row23_col2, #T_d96a1_row23_col5, #T_d96a1_row23_col6, #T_d96a1_row23_col7, #T_d96a1_row23_col8, #T_d96a1_row24_col0, #T_d96a1_row24_col1, #T_d96a1_row24_col2, #T_d96a1_row24_col5, #T_d96a1_row24_col6, #T_d96a1_row24_col7, #T_d96a1_row24_col8, #T_d96a1_row25_col0, #T_d96a1_row25_col1, #T_d96a1_row25_col2, #T_d96a1_row25_col5, #T_d96a1_row25_col6, #T_d96a1_row25_col7, #T_d96a1_row25_col8, #T_d96a1_row26_col0, #T_d96a1_row26_col1, #T_d96a1_row26_col2, #T_d96a1_row26_col5, #T_d96a1_row26_col6, #T_d96a1_row26_col7, #T_d96a1_row26_col8, #T_d96a1_row27_col0, #T_d96a1_row27_col1, #T_d96a1_row27_col2, #T_d96a1_row27_col5, #T_d96a1_row27_col6, #T_d96a1_row27_col7, #T_d96a1_row27_col8, #T_d96a1_row28_col0, #T_d96a1_row28_col1, #T_d96a1_row28_col2, #T_d96a1_row28_col5, #T_d96a1_row28_col6, #T_d96a1_row28_col7, #T_d96a1_ ...
