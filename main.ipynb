# %% [markdown]
# Set your parameters

# %%
# What is your major?
MAJOR_SUPPORT = "CISC"
# Do you need FE courses recommendation?
FE_SUPPORT = False
# What is the academic year now?
YEAR_SUPPORT = "2024a"
# How many suggestion do you want?
SUGGESTION_NUM = 30

# %%
import numpy as np
import pandas as pd
from datetime import datetime, timedelta

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.expand_frame_repr', False)

# %% [markdown]
# Convert your timetable into special data structure. You can use AI tools like GPT-4 or Claude-3.5 to accomplish this. In this case, you may need to use the following prompt:
# ```
# my_timetable = [
# {
# "course_code": "GEST1009",
# "day": "MON",
# "start_time": "08:30",
# "end_time": "09:45",
# "type": "Lecture"
# },
# {
# "course_code": "GEST1009",
# "day": "THU",
# "start_time": "08:30",
# "end_time": "09:45",
# "type": "Lecture"
# },
# {
# "course_code": "CISC1002",
# "day": "MON",
# "start_time": "11:30",
# "end_time": "12:45",
# "type": "Lecture"
# },
# # ... (continue for all other classes)
# ]
#
# Convert all the data from the timetable image into the format shown above.
# ```

# %%
timetable = [
    {
        "course_code": "GEST1009",
        "day": "MON",
        "start_time": "08:30",
        "end_time": "09:45",
        "type": "Lecture"
    },
    {
        "course_code": "GEST1009",
        "day": "THU",
        "start_time": "08:30",
        "end_time": "09:45",
        "type": "Lecture"
    },
    {
        "course_code": "CISC1002",
        "day": "MON",
        "start_time": "11:30",
        "end_time": "12:45",
        "type": "Lecture"
    },
    {
        "course_code": "CISC1002",
        "day": "THU",
        "start_time": "11:30",
        "end_time": "12:45",
        "type": "Lecture"
    },
    {
        "course_code": "CISC1002",
        "day": "FRI",
        "start_time": "10:00",
        "end_time": "11:15",
        "type": "Lab/Tutorial"
    },
    {
        "course_code": "GEGA1000",
        "day": "TUE",
        "start_time": "14:30",
        "end_time": "15:45",
        "type": "Lecture"
    },
    {
        "course_code": "GEGA1000",
        "day": "FRI",
        "start_time": "14:30",
        "end_time": "15:45",
        "type": "Lecture"
    },
    {
        "course_code": "CISC2001",
        "day": "MON",
        "start_time": "16:00",
        "end_time": "17:15",
        "type": "Lecture"
    },
    {
        "course_code": "CISC2001",
        "day": "THU",
        "start_time": "16:00",
        "end_time": "17:15",
        "type": "Lecture"
    },
    {
        "course_code": "CISC2001",
        "day": "FRI",
        "start_time": "17:30",
        "end_time": "18:45",
        "type": "Lab/Tutorial"
    },
    {
        "course_code": "CISC2003",
        "day": "TUE",
        "start_time": "16:00",
        "end_time": "17:15",
        "type": "Lecture"
    },
    {
        "course_code": "CISC2003",
        "day": "WED",
        "start_time": "16:00",
        "end_time": "17:15",
        "type": "Lab/Tutorial"
    },
    {
        "course_code": "CISC2003",
        "day": "FRI",
        "start_time": "16:00",
        "end_time": "17:15",
        "type": "Lecture"
    },
    {
        "course_code": "HONR2003",
        "day": "WED",
        "start_time": "18:30",
        "end_time": "21:15",
        "type": "Lecture"
    }
]

# %%
cm = pd.read_csv("2024a/cm.csv").dropna(axis=0)
ge = pd.read_csv("2024a/ge.csv").dropna(axis=0)

# %%
if FE_SUPPORT == True:
    df = pd.concat([cm, ge], ignore_index=True)
else:
    cm = cm[cm['course_name'].str.startswith(f'{MAJOR_SUPPORT}', na=False)]
    df = pd.concat([cm, ge], ignore_index=True)

# %%
grade_order = {
    'A+': 12, 'A': 11, 'A-': 10,
    'B+': 9, 'B': 8, 'B-': 7,
    'C+': 6, 'C': 5, 'C-': 4,
    'D+': 3, 'D': 2, 'D-': 1,
    'F': 0
}

def grade_to_numeric(grade):
    return grade_order.get(grade, -1) 

df = df.sort_values(
    by=['overall_grade', 'course_name', 'name'],
    key=lambda x: x.map(lambda y: grade_to_numeric(y) if x.name == 'overall_grade' else y),
    ascending=[False, True, True]
)

# %%
def parse_time(time_str):
    return datetime.strptime(time_str, '%H:%M')

def check_conflict(existing_class, new_class):
    if existing_class['day'] != new_class['day']:
        return False
    
    existing_start = parse_time(existing_class['start_time'])
    existing_end = parse_time(existing_class['end_time'])
    new_start = parse_time(new_class['start_time'])
    new_end = parse_time(new_class['end_time'])
    
    return (existing_start <= new_start < existing_end) or \
           (existing_start < new_end <= existing_end) or \
           (new_start <= existing_start and existing_end <= new_end)

def parse_course_time(time_str):
    time_slots = []
    for slot in time_str.split('&'):
        day, time_range = slot.strip().split(' ', 1)
        start_time, end_time = time_range.split('-')
        time_slots.append({
            'day': day,
            'start_time': start_time,
            'end_time': end_time
        })
    return time_slots

def has_conflict_with_timetable(course_time, my_timetable):
    course_slots = parse_course_time(course_time)
    for new_slot in course_slots:
        for existing_class in my_timetable:
            if check_conflict(existing_class, new_slot):
                return True
    return False

# %%
def show(df, timetable):
    non_conflicting_courses = df[~df['time'].apply(lambda x: has_conflict_with_timetable(x, timetable))]
    print(non_conflicting_courses[:SUGGESTION_NUM].to_string(index=False))

# %%
df
# Out:
#     course_name                                               name  section overall_grade grade difficulty useful  comments                                               time
# 0      CISC3001                                            WU YUAN        1             A     A          A      A         3  MON 17:30-18:45 & THU 17:30-18:45 & WED 10:00-...
# 16     GELH1001                                      CHEONG IM LAN        3             A     A          A      A        10                  MON 14:30-15:45 & THU 14:30-15:45
# 17     GELH1001                                      CHEONG IM LAN        4             A     A          A      A        10                  MON 16:00-17:15 & THU 16:00-17:15
# 18     GELH1007                                           LI ZIHAO        1             A     A          A      A         2                                    SAT 08:30-11:15
# 19     GEST2002                                   KUZMA STRELNIKOV        1             A     A          A      A         2                  MON 11:30-12:45 & THU 11:30-12:45
# 20     GELH1000                                        SUN XIAOXUE       10            A-     A          A      A         1                  MON 08:30-09:45 & THU 08:30-09:45
# 21     GELH1010                                      LEE TING MIEN        1            A-     A          A      A         1                  FRI 08:30-09:45 & TUE 08:30-09:45
# 1      CISC3014                                      WANG PENGYANG        1            B+     B          B     B+         7                  MON 14:30-15:45 & THU 14:30-15:45
# 22     GEGA1006                                       ZHA CHENYANG        4            B+    A-         A-     A-        18                  FRI 17:30-18:45 & TUE 17:30-18:45
# 23     GELH2001                           JEREMY CENTENO DE CHAVEZ        1            B+     A         B+     B+        18                                    MON 10:00-12:45
# 24     GELH2001                           JEREMY CENTENO DE CHAVEZ        2            B+     A         B+     B+        18                                    FRI 16:00-18:45
# 25     GEST1003                                       WAN LUNG YAM        1            B+    A-         A-     B+         6                  MON 11:30-12:45 & THU 11:30-12:45
# 2      CISC1004                       MIGUEL JUNIOR GOMES DA COSTA        1             B    A-          B     B+        39                  MON 14:30-15:45 & THU 14:30-15:45
# 3      CISC3029                                       ZHANG LIMING        1             B    B+         B+      B         9                  FRI 14:30-15:45 & TUE 14:30-15:45
# 26     GEGA1006                                       SUN PENGZHAN        2             B    B+         B+      B        12                  MON 16:00-17:15 & THU 16:00-17:15
# 27     GELH2004                         WEATHERLY CHRISTOPHER ALAN        1             B    B-         B-     B-         5                                    TUE 19:00-21:45
# 28     GESB1003                                            KONG WA        7             B    A-         A-     B+        23                  MON 13:00-14:15 & THU 13:00-14:15
# 29     GESB1003                                            KONG WA        8             B    A-         A-     B+        23                  MON 13:00-14:15 & THU 13:00-14:15
# 30     GESB1003                                            KONG WA        9             B    A-         A-     B+        23                  MON 13:00-14:15 & THU 13:00-14:15
# 31     GEST1004                                        KOU KIT IAN        2             B     A          C      A         1  MON 10:00-11:15 & THU 10:00-11:15 & WED 10:00-...
# 32     GEST1006                                        WU IOK KUAN        1             B    B+         B+      B        15                  MON 16:00-17:15 & THU 16:00-17:15
# 33     GEST1006                                        WU IOK KUAN        2             B    B+         B+      B        15                  FRI 16:00-17:15 & TUE 16:00-17:15
# 34     GEST1016                                        SUN GUOXING        1             B    B+          B      B        66                  MON 16:00-17:15 & THU 16:00-17:15
# 35     GEST1017  CHEANG WAI SAN / LU JIAHONG / UNG OI LAM CAROLINA        1             B    A-         A-     B+         7                  MON 14:30-15:45 & THU 14:30-15:45
# 4      CISC2001                                              LI LI        1            B-    B-         B-     B-        38  FRI 17:30-18:45 & MON 16:00-17:15 & THU 16:00-...
# 5      CISC3007                                     YIBO BOB ZHANG        1            B-     B         C+     B+         5                  MON 14:30-15:45 & THU 14:30-15:45
# 6      CISC3023                                          CHEN LONG        1            B-    B-          C     B-        23                  MON 10:00-11:15 & THU 10:00-11:15
# 7      CISC3028                       MIGUEL JUNIOR GOMES DA COSTA        1            B-     B         B-      B         8                  FRI 17:30-18:45 & TUE 17:30-18:45
# 36     GEGA1000                                       XIE JINGZHEN        1            B-     B         B+     C+         4                  MON 14:30-15:45 & THU 14:30-15:45
# 37     GEGA1003                     ROSTAM MAG.IUR.DR.IUR.NEUWIRTH        1            B-    B-         B+     B-        19                  MON 08:30-09:45 & THU 08:30-09:45
# 38     GEGA1006                                        SHAO HUAIYU        1            B-    B+         B-      B        37                  MON 08:30-09:45 & THU 08:30-09:45
# 39     GEGA1006                                      XING GUICHUAN        3            B-     B          B     C+        40                  FRI 16:00-17:15 & TUE 16:00-17:15
# 40     GEGA3001                                           YANG HAI        1            B-     B          C      B        28                  MON 16:00-17:15 & THU 16:00-17:15
# 41     GEGA3001                                           YANG HAI        2            B-     B          C      B        28                  FRI 14:30-15:45 & TUE 14:30-15:45
# 42     GELH1000                                      CHEONG IM LAN        4            B-    B+          B     B+        69                  FRI 10:00-11:15 & TUE 10:00-11:15
# 43     GELH1000                                      CHEONG IM LAN        5            B-    B+          B     B+        69                  FRI 11:30-12:45 & TUE 11:30-12:45
# 44     GELH1000                                      CHEONG IM LAN        6            B-    B+          B     B+        69                  FRI 14:30-15:45 & TUE 14:30-15:45
# 45     GEST1001                                         JIAO YIFAN        6            B-     B         B-      B         4                  MON 16:00-17:15 & THU 16:00-17:15
# 46     GEST1001                                         JIAO YIFAN        7            B-     B         B-      B         4                  FRI 16:00-17:15 & TUE 16:00-17:15
# 47     GEST1002                                       LEI CHON LOK        4            B-     A          B     A-        33                  MON 08:30-09:45 & THU 08:30-09:45
# 48     GEST1004                              CHENG CHE MAN RAYMOND        1            B-    B-          C     C+        14  MON 16:00-17:15 & THU 16:00-17:15 & WED 11:00-...
# 49     GEST1012                                       TAM KAM WENG        1            B-    B-          B      C        12                  MON 08:30-09:45 & THU 08:30-09:45
# 50     GEST1014                                       LIAO JINFENG        1            B-    B-         B-     B-         6                  MON 17:30-18:45 & THU 17:30-18:45
# 51     GELH1000                                     CHEANG WAI LEK       17            C+     B          B     B-        37                  MON 17:30-18:45 & THU 17:30-18:45
# 52     GELH1000                                     CHEANG WAI LEK       18            C+     B          B     B-        37                  FRI 17:30-18:45 & TUE 17:30-18:45
# 53     GELH1000                                     CHEANG WAI LEK       19            C+     B          B     B-        37                                    SAT 10:00-12:45
# 54     GELH1001                                        WANG MINGYU        1            C+    B-         B-     B-        31                  MON 13:00-14:15 & THU 13:00-14:15
# 55     GELH1001                                        WANG MINGYU        2            C+    B-         B-     B-        31                  FRI 17:30-18:45 & TUE 17:30-18:45
# 56     GELH2003                                     VONG WENG CHON        1            C+    B-         C+      B        62                                    WED 10:00-12:45
# 57     GELH2003                                     VONG WENG CHON        2            C+    B-         C+      B        62                                    THU 10:00-12:45
# 58     GELH2003                                     VONG WENG CHON        3            C+    B-         C+      B        62                                    FRI 10:00-12:45
# 59     GELH2005                                        CAI GUO JIE        1            C+     B          B      B         7                                    WED 10:00-12:45
# 60     GESB1002                                       KOU KEI SANG       16            C+    B-         C+     B-       122                  FRI 16:00-17:15 & TUE 16:00-17:15
# 61     GESB1002                                       KOU KEI SANG       17            C+    B-         C+     B-       122                  FRI 16:00-17:15 & TUE 16:00-17:15
# 62     GESB1002                                       KOU KEI SANG       18            C+    B-         C+     B-       122                  FRI 16:00-17:15 & TUE 16:00-17:15
# 63     GESB1005                                        HO HENG MAN        1            C+    B+          B     B-        24                  MON 16:00-17:15 & THU 16:00-17:15
# 64     GESB1005                                        HO HENG MAN        2            C+    B+          B     B-        24                  MON 14:30-15:45 & THU 14:30-15:45
# 65     GEST1001                                       KUAN UN FONG        3            C+     B          B      B        40                  MON 11:30-12:45 & THU 11:30-12:45
# 66     GEST1001                                       KUAN UN FONG        4            C+     B          B      B        40                  FRI 13:00-14:15 & TUE 13:00-14:15
# 67     GEST1001                                       KUAN UN FONG        5            C+     B          B      B        40                  FRI 14:30-15:45 & TUE 14:30-15:45
# 68     GEST1001                                        LAO WUN LEI        1            C+    B-         C+     B-        45                  MON 13:00-14:15 & THU 13:00-14:15
# 69     GEST1001                                        LAO WUN LEI        2            C+    B-         C+     B-        45                  MON 14:30-15:45 & THU 14:30-15:45
# 70     GEST1001                                        LAO WUN LEI        8            C+    B-         C+     B-        45                  FRI 11:30-12:45 & TUE 11:30-12:45
# 71     GEST1002                            WANG PENG / WANG YA FAN        1            C+    A-         A-     B-         2                  FRI 11:30-12:45 & TUE 11:30-12:45
# 72     GEST1004                                       WAN LUNG YAM        3            C+     B         C+     C+        35  FRI 16:00-17:15 & TUE 16:00-17:15 & WED 10:00-...
# 73     GEST1004                                       WAN LUNG YAM        4            C+     B         C+     C+        35  MON 14:30-15:45 & THU 14:30-15:45 & TUE 11:30-...
# 74     GEST1004                                       WAN LUNG YAM        5            C+     B         C+     C+        35  FRI 10:00-10:50 & MON 10:00-11:15 & THU 10:00-...
# 75     GEST1007                           GARY WONG / WONG KOON HO        1            C+    B-         C+     B-        81                  MON 08:30-09:45 & THU 08:30-09:45
# 76     GEST1007                           GARY WONG / WONG KOON HO        2            C+    B-         C+     B-        81                  FRI 10:00-11:15 & TUE 10:00-11:15
# 77     GEST1015                                         NG KAR WEI        1            C+     B         B-     B-        20                  MON 17:30-18:45 & THU 17:30-18:45
# 8      CISC2003                                       ZHANG LIMING        1             C     C         C-     C+        43  FRI 16:00-17:15 & TUE 16:00-17:15 & WED 16:00-...
# 9      CISC3024                                        ZHOU YICONG        1             C    B-          C      C        18                  MON 13:00-14:15 & THU 13:00-14:15
# 78     GEGA1000                                  LIAO BOLUN, EDGAR        5             C     C          C      C         3                  MON 08:30-09:45 & THU 08:30-09:45
# 79     GEGA1000                                  LIAO BOLUN, EDGAR        6             C     C          C      C         3                  MON 10:00-11:15 & THU 10:00-11:15
# 80     GEGA1000                                  LIAO BOLUN, EDGAR        7             C     C          C      C         3                  MON 13:00-14:15 & THU 13:00-14:15
# 81     GEGA1000                                SPOONER PAUL BARRIE        8             C    C+         C-      C        77                  FRI 08:30-09:45 & TUE 08:30-09:45
# 82     GEGA1000                                SPOONER PAUL BARRIE        9             C    C+         C-      C        77                  FRI 10:00-11:15 & TUE 10:00-11:15
# 83     GEGA1000                                SPOONER PAUL BARRIE       10             C    C+         C-      C        77                  FRI 13:00-14:15 & TUE 13:00-14:15
# 84     GELH1000                                       CHAN WAI CHU       14             C     C          C     C-        20                  MON 10:00-11:15 & THU 10:00-11:15
# 85     GELH1000                                       CHAN WAI CHU       15             C     C          C     C-        20                  SAT 10:00-11:15 & WED 10:00-11:15
# 86     GELH1000                                       CHAN WAI CHU       16             C     C          C     C-        20                  SAT 11:30-12:45 & WED 11:30-12:45
# 87     GELH1000                                     SIO CHIO IEONG        1             C    B-         C+     C-        37                  MON 10:00-11:15 & THU 10:00-11:15
# 88     GELH1000                                     SIO CHIO IEONG        2             C    B-         C+     C-        37                  MON 11:30-12:45 & THU 11:30-12:45
# 89     GELH1000                                     SIO CHIO IEONG        3             C    B-         C+     C-        37                  FRI 13:00-14:15 & TUE 13:00-14:15
# 90     GELH2002                                    GLEN TIMMERMANS        1             C    C+         C-     B-        81                                    FRI 10:00-12:45
# 91     GESB1002                                DIMITRA AMARANTIDOU        1             C     C         C-     C+       106                  MON 10:00-11:15 & THU 10:00-11:15
# 92     GESB1002                                DIMITRA AMARANTIDOU        2             C     C         C-     C+       106                  MON 10:00-11:15 & THU 10:00-11:15
# 93     GESB1002                                DIMITRA AMARANTIDOU        3             C     C         C-     C+       106                  MON 10:00-11:15 & THU 10:00-11:15
# 94     GESB1002                                DIMITRA AMARANTIDOU        4             C     C         C-     C+       106                  FRI 11:30-12:45 & TUE 11:30-12:45
# 95     GESB1002                                DIMITRA AMARANTIDOU        5             C     C         C-     C+       106                  FRI 11:30-12:45 & TUE 11:30-12:45
# 96     GESB1002                                DIMITRA AMARANTIDOU        6             C     C         C-     C+       106                  FRI 11:30-12:45 & TUE 11:30-12:45
# 97     GESB1002                                DIMITRA AMARANTIDOU        7             C     C         C-     C+       106                  MON 13:00-14:15 & THU 13:00-14:15
# 98     GESB1002                                DIMITRA AMARANTIDOU        8             C     C         C-     C+       106                  MON 13:00-14:15 & THU 13:00-14:15
# 99     GESB1002                                DIMITRA AMARANTIDOU        9             C     C         C-     C+       106                  MON 13:00-14:15 & THU 13:00-14:15
# 100    GESB1002                                DIMITRA AMARANTIDOU       10             C     C         C-     C+       106                  FRI 14:30-15:45 & TUE 14:30-15:45
# 101    GESB1002                                DIMITRA AMARANTIDOU       11             C     C         C-     C+       106                  FRI 14:30-15:45 & TUE 14:30-15:45
# 102    GESB1002                                DIMITRA AMARANTIDOU       12             C     C         C-     C+       106                  FRI 14:30-15:45 & TUE 14:30-15:45
# 103    GESB1002                                DIMITRA AMARANTIDOU       13             C     C         C-     C+       106                  MON 14:30-15:45 & THU 14:30-15:45
# 104    GESB1002                                DIMITRA AMARANTIDOU       14             C     C         C-     C+       106                  MON 14:30-15:45 & THU 14:30-15:45
# 105    GESB1002                                DIMITRA AMARANTIDOU       15             C     C         C-     C+       106                  MON 14:30-15:45 & THU 14:30-15:45
# 106    GESB1003                                        LAI KUAN JU        1             C    B-         B-     C+        79                  MON 10:00-11:15 & THU 10:00-11:15
# 107    GESB1003                                        LAI KUAN JU        2             C    B-         B-     C+        79                  MON 10:00-11:15 & THU 10:00-11:15
# 108    GESB1003                                        LAI KUAN JU        3             C    B-         B-     C+        79                  MON 10:00-11:15 & THU 10:00-11:15
# 109    GESB1003                                        LAI KUAN JU        4             C    B-         B-     C+        79                  FRI 11:30-12:45 & TUE 11:30-12:45
# 110    GESB1003                                        LAI KUAN JU        5             C    B-         B-     C+        79                  FRI 11:30-12:45 & TUE 11:30-12:45
# 111    GESB1003                                        LAI KUAN JU        6             C    B-         B-     C+        79                  FRI 11:30-12:45 & TUE 11:30-12:45
# 112    GESB1006                                       MINGLI ZHENG        1             C     C         C+     C-        35                  FRI 10:00-11:15 & TUE 10:00-11:15
# 113    GESB2001                                      JA YOUNG CHOE        1             C    C+          C     C+        12                  FRI 14:30-15:45 & TUE 14:30-15:45
# 114    GESB2003                             JOSEPH ADEA SY-CHANGCO        1             C    C+         C+     C-        20                  FRI 13:00-14:15 & TUE 13:00-14:15
# 115    GESB2003                             JOSEPH ADEA SY-CHANGCO        2             C    C+         C+     C-        20                  MON 16:00-17:15 & THU 16:00-17:15
# 116    GESB2003                             JOSEPH ADEA SY-CHANGCO        3             C    C+         C+     C-        20                  FRI 17:30-18:45 & TUE 17:30-18:45
# 117    GEST1002                            JUNG WOO PARK / WANG LI        2             C    B-          B     C-        13                  MON 16:00-17:15 & THU 16:00-17:15
# 118    GEST1005                               CHAN WING HAN BRENDA        1             C    C-         C+     D+        58                  MON 08:30-09:45 & THU 08:30-09:45
# 119    GEST1009                                           LAM TENG        1             C    C+          C     C+        34                  MON 08:30-09:45 & THU 08:30-09:45
# 120    GEST1010                                        IP WENG FAI        1             C    D+         C-     D+        15                  FRI 10:00-11:15 & TUE 10:00-11:15
# 121    GEST1019                                      ZHANG MINGLEI        1             C    C+         C+      C        41                  FRI 08:30-09:45 & TUE 08:30-09:45
# 122    GEGA2003                                  SOU VA IAN SUZANA        1            C-     C          D     B-        24                  FRI 13:00-14:15 & TUE 13:00-14:15
# 123    GELH1000                                     LAO KENG CHONG       12            C-    D+         C+      D        30                  MON 14:30-15:45 & THU 14:30-15:45
# 124    GELH1000                                     LAO KENG CHONG       13            C-    D+         C+      D        30                  FRI 10:00-11:15 & TUE 10:00-11:15
# 125    GELH1000                                          LO IN FAT        8            C-    C-         C-     D+        36                  FRI 08:30-09:45 & TUE 08:30-09:45
# 126    GELH1000                                        MA WAN CHAM       11            C-    C-          C     C-       168                  FRI 17:30-18:45 & TUE 17:30-18:45
# 127    GESB1001                                        KUOK OI MEI        1            C-    C-          C     D+        38                  MON 10:00-11:15 & THU 10:00-11:15
# 128    GESB1001                                        KUOK OI MEI        2            C-    C-          C     D+        38                  MON 10:00-11:15 & THU 10:00-11:15
# 129    GESB1001                                        KUOK OI MEI        3            C-    C-          C     D+        38                  MON 10:00-11:15 & THU 10:00-11:15
# 130    GESB1001                                        KUOK OI MEI        4            C-    C-          C     D+        38                  FRI 11:30-12:45 & TUE 11:30-12:45
# 131    GESB1001                                        KUOK OI MEI        5            C-    C-          C     D+        38                  FRI 11:30-12:45 & TUE 11:30-12:45
# 132    GESB1001                                        KUOK OI MEI        6            C-    C-          C     D+        38                  FRI 11:30-12:45 & TUE 11:30-12:45
# 133    GESB1001                                        KUOK OI MEI        7            C-    C-          C     D+        38                  MON 13:00-14:15 & THU 13:00-14:15
# 134    GESB1001                                        KUOK OI MEI        8            C-    C-          C     D+        38                  MON 13:00-14:15 & THU 13:00-14:15
# 135    GESB1001                                        KUOK OI MEI        9            C-    C-          C     D+        38                  MON 13:00-14:15 & THU 13:00-14:15
# 136    GESB1001                                        KUOK OI MEI       10            C-    C-          C     D+        38                  FRI 14:30-15:45 & TUE 14:30-15:45
# 137    GESB1001                                        KUOK OI MEI       11            C-    C-          C     D+        38                  FRI 14:30-15:45 & TUE 14:30-15:45
# 138    GESB1001                                        KUOK OI MEI       12            C-    C-          C     D+        38                  FRI 14:30-15:45 & TUE 14:30-15:45
# 139    GESB2002                                        ZHANG LIWEN        1            C-    D+         D+     C-        11                  MON 10:00-11:15 & THU 10:00-11:15
# 10     CISC3026                                       SI YAIN WHAR        1            D+    C-         D+      D        17                  FRI 11:30-12:45 & TUE 11:30-12:45
# 140    GEGA1000                                          WEN RUJIA        2            D+    C-         D+     C-       279                  FRI 14:30-15:45 & TUE 14:30-15:45
# 141    GEGA1000                                          WEN RUJIA        3            D+    C-         D+     C-       279                  FRI 16:00-17:15 & TUE 16:00-17:15
# 142    GEGA1000                                          WEN RUJIA        4            D+    C-         D+     C-       279                  MON 16:00-17:15 & THU 16:00-17:15
# 143    GELH2008                                       LEI WAI SENG        1            D+    C-          D     D+        16                  MON 10:00-11:15 & THU 10:00-11:15
# 144    GESB1001                               LEUNG KHALILIAN ROSE       13            D+    D+         D+     D+       447                  MON 14:30-15:45 & THU 14:30-15:45
# 145    GESB1001                               LEUNG KHALILIAN ROSE       14            D+    D+         D+     D+       447                  MON 14:30-15:45 & THU 14:30-15:45
# 146    GESB1001                               LEUNG KHALILIAN ROSE       15            D+    D+         D+     D+       447                  MON 14:30-15:45 & THU 14:30-15:45
# 147    GESB1001                               LEUNG KHALILIAN ROSE       16            D+    D+         D+     D+       447                  FRI 16:00-17:15 & TUE 16:00-17:15
# 148    GESB1001                               LEUNG KHALILIAN ROSE       17            D+    D+         D+     D+       447                  FRI 16:00-17:15 & TUE 16:00-17:15
# 149    GESB1001                               LEUNG KHALILIAN ROSE       18            D+    D+         D+     D+       447                  FRI 16:00-17:15 & TUE 16:00-17:15
# 150    GESB1013                                     LEUNG SHING ON        1            D+    D+          C     D-        34                  FRI 11:30-12:45 & TUE 11:30-12:45
# 151    GEST1008                                       WAN IAT MENG        1            D+    C-          D     C-        28                  FRI 08:30-09:45 & TUE 08:30-09:45
# 11     CISC1001                                           XU QIWEN        1             D     D         D-      D       253  MON 10:00-11:15 & THU 10:00-11:15 & WED 16:00-...
# 152    GELH1000                                         CHEN ZHONG        9             D     D         D+      D        42                  FRI 16:00-17:15 & TUE 16:00-17:15
# 153    GESB1009                                      CHANG SIO NGA        1             D     D          D     D-        82                  MON 08:30-09:45 & THU 08:30-09:45
# 154    GESB2004                                         CAROL TING        1             D     D          C      D         1                  FRI 16:00-17:15 & TUE 16:00-17:15
# 12     CISC1002                                           XU QIWEN        1            D-    D-         D-     D-       200  FRI 10:00-11:15 & MON 11:30-12:45 & THU 11:30-...
# 13     CISC2007                                           LAM TENG        1            D-    D-         D-     D-         4                  MON 14:30-15:45 & THU 14:30-15:45
# 14     CISC3012                                       VONG CHI MAN        1            D-    D-          D      F        35                  FRI 10:00-11:15 & TUE 10:00-11:15
# 15     CISC3015                                        VAT KAM HOU        1            D-     D          F     D-        16                  MON 16:00-17:15 & THU 16:00-17:15

# %%
def style_dataframe(df):
    def highlight_grades(val):
        color_map = {
            'A': '#4CAF50',  # 绿色
            'A-': '#8BC34A',
            'B+': '#2196F3', # 蓝色
            'B': '#03A9F4',
            'B-': '#00BCD4',
            'C+': '#FFC107', # 琥珀色
            'C': '#FFB300',
            'C-': '#FFA000',
            'D': '#FF5722',  # 深橙色
            'F': '#F44336'   # 红色
        }
        return f'color: {color_map.get(val, "#212529")}; font-weight: bold;'

    return (df.style
            .set_properties(**{
                'background-color': '#f8f9fa',
                'color': '#212529',
                'border-color': '#dee2e6',
                'font-family': 'Arial, sans-serif',
                'font-size': '12px',
                'text-align': 'left',
                'white-space': 'normal',  # 允许文本换行
                'max-width': '150px'
            })
            .set_table_styles([
                {'selector': 'th', 'props': [
                    ('background-color', '#e9ecef'),
                    ('color', '#495057'),
                    ('font-weight', 'bold'),
                    ('text-align', 'left'),
                    ('padding', '12px'),
                    ('border-bottom', '2px solid #dee2e6')
                ]},
                {'selector': 'td', 'props': [('padding', '12px')]},
                {'selector': 'tr:nth-of-type(even)', 'props': [('background-color', '#ffffff')]},
            ])
            .map(highlight_grades, subset=['overall_grade', 'grade'])
            .highlight_max(subset=['difficulty', 'useful'], color='#fce4ec')
            .highlight_min(subset=['difficulty', 'useful'], color='#e8f5e9')
           )
def show():
    styled_df = style_dataframe(df)
    display(styled_df)

# %%
show()
# Out:
# <style type="text/css">
# #T_f2153 th {
#   background-color: #e9ecef;
#   color: #495057;
#   font-weight: bold;
#   text-align: left;
#   padding: 12px;
#   border-bottom: 2px solid #dee2e6;
# }
# #T_f2153 td {
#   padding: 12px;
# }
# #T_f2153 tr:nth-of-type(even) {
#   background-color: #ffffff;
# }
# #T_f2153_row0_col0, #T_f2153_row0_col1, #T_f2153_row0_col2, #T_f2153_row0_col7, #T_f2153_row0_col8, #T_f2153_row1_col0, #T_f2153_row1_col1, #T_f2153_row1_col2, #T_f2153_row1_col7, #T_f2153_row1_col8, #T_f2153_row2_col0, #T_f2153_row2_col1, #T_f2153_row2_col2, #T_f2153_row2_col7, #T_f2153_row2_col8, #T_f2153_row3_col0, #T_f2153_row3_col1, #T_f2153_row3_col2, #T_f2153_row3_col7, #T_f2153_row3_col8, #T_f2153_row4_col0, #T_f2153_row4_col1, #T_f2153_row4_col2, #T_f2153_row4_col7, #T_f2153_row4_col8, #T_f2153_row5_col0, #T_f2153_row5_col1, #T_f2153_row5_col2, #T_f2153_row5_col7, #T_f2153_row5_col8, #T_f2153_row6_col0, #T_f2153_row6_col1, #T_f2153_row6_col2, #T_f2153_row6_col7, #T_f2153_row6_col8, #T_f2153_row7_col0, #T_f2153_row7_col1, #T_f2153_row7_col2, #T_f2153_row7_col5, #T_f2153_row7_col6, #T_f2153_row7_col7, #T_f2153_row7_col8, #T_f2153_row8_col0, #T_f2153_row8_col1, #T_f2153_row8_col2, #T_f2153_row8_col5, #T_f2153_row8_col6, #T_f2153_row8_col7, #T_f2153_row8_col8, #T_f2153_row9_col0, #T_f2153_row9_col1, #T_f2153_row9_col2, #T_f2153_row9_col5, #T_f2153_row9_col6, #T_f2153_row9_col7, #T_f2153_row9_col8, #T_f2153_row10_col0, #T_f2153_row10_col1, #T_f2153_row10_col2, #T_f2153_row10_col5, #T_f2153_row10_col6, #T_f2153_row10_col7, #T_f2153_row10_col8, #T_f2153_row11_col0, #T_f2153_row11_col1, #T_f2153_row11_col2, #T_f2153_row11_col5, #T_f2153_row11_col6, #T_f2153_row11_col7, #T_f2153_row11_col8, #T_f2153_row12_col0, #T_f2153_row12_col1, #T_f2153_row12_col2, #T_f2153_row12_col5, #T_f2153_row12_col6, #T_f2153_row12_col7, #T_f2153_row12_col8, #T_f2153_row13_col0, #T_f2153_row13_col1, #T_f2153_row13_col2, #T_f2153_row13_col5, #T_f2153_row13_col6, #T_f2153_row13_col7, #T_f2153_row13_col8, #T_f2153_row14_col0, #T_f2153_row14_col1, #T_f2153_row14_col2, #T_f2153_row14_col5, #T_f2153_row14_col6, #T_f2153_row14_col7, #T_f2153_row14_col8, #T_f2153_row15_col0, #T_f2153_row15_col1, #T_f2153_row15_col2, #T_f2153_row15_col5, #T_f2153_row15_col6, #T_f2153_row15_col7, #T_f2153_row15_col8, #T_f2153_row16_col0, #T_f2153_row16_col1, #T_f2153_row16_col2, #T_f2153_row16_col5, #T_f2153_row16_col6, #T_f2153_row16_col7, #T_f2153_row16_col8, #T_f2153_row17_col0, #T_f2153_row17_col1, #T_f2153_row17_col2, #T_f2153_row17_col5, #T_f2153_row17_col6, #T_f2153_row17_col7, #T_f2153_row17_col8, #T_f2153_row18_col0, #T_f2153_row18_col1, #T_f2153_row18_col2, #T_f2153_row18_col5, #T_f2153_row18_col6, #T_f2153_row18_col7, #T_f2153_row18_col8, #T_f2153_row19_col0, #T_f2153_row19_col1, #T_f2153_row19_col2, #T_f2153_row19_col5, #T_f2153_row19_col7, #T_f2153_row19_col8, #T_f2153_row20_col0, #T_f2153_row20_col1, #T_f2153_row20_col2, #T_f2153_row20_col5, #T_f2153_row20_col6, #T_f2153_row20_col7, #T_f2153_row20_col8, #T_f2153_row21_col0, #T_f2153_row21_col1, #T_f2153_row21_col2, #T_f2153_row21_col5, #T_f2153_row21_col6, #T_f2153_row21_col7, #T_f2153_row21_col8, #T_f2153_row22_col0, #T_f2153_row22_col1, #T_f2153_row22_col2, #T_f2153_row22_col5, #T_f2153_row22_col6, #T_f2153_row22_col7, #T_f2153_row22_col8, #T_f2153_row23_col0, #T_f2153_row23_col1, #T_f2153_row23_col2, #T_f2153_row23_col5, #T_f2153_row23_col6, #T_f2153_row23_col7, #T_f2153_row23_col8, #T_f2153_row24_col0, #T_f2153_row24_col1, #T_f2153_row24_col2, #T_f2153_row24_col5, #T_f2153_row24_col6, #T_f2153_row24_col7, #T_f2153_row24_col8, #T_f2153_row25_col0, #T_f2153_row25_col1, #T_f2153_row25_col2, #T_f2153_row25_col5, #T_f2153_row25_col6, #T_f2153_row25_col7, #T_f2153_row25_col8, #T_f2153_row26_col0, #T_f2153_row26_col1, #T_f2153_row26_col2, #T_f2153_row26_col5, #T_f2153_row26_col6, #T_f2153_row26_col7, #T_f2153_row26_col8, #T_f2153_row27_col0, #T_f2153_row27_col1, #T_f2153_row27_col2, #T_f2153_row27_col5, #T_f2153_row27_col6, #T_f2153_row27_col7, #T_f2153_row27_col8, #T_f2153_row28_col0, #T_f2153_row28_col1, #T_f2153_row28_col2, #T_f2153_row28_col5, #T_f2153_row28_col6, #T_f2153_row28_col7, #T_f2153_row28_col8, #T_f2153_row29_col0, #T_f2153_row29_col1, #T_f2153_row29_col2, #T_f2153_row29_col5, #T_f2153_row29_col6, #T_ ...
